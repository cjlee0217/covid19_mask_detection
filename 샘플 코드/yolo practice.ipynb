# %%
# 참고 사이트
# https://lv99.tistory.com/72

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive')

# %%
# !git clone https://github.com/ultralytics/yolov5 
# !pip install -r yolov5/requirements.txt 
# %cd yolov5

import torch
from IPython.display import Image, clear_output
from utils.google_utils import gdrive_download

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 CPU

# %%
# # Start tensorboard
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python train.py --img 149 --batch 16 --epochs 5 --data ./mask/data.yaml \
--cfg ./models/yolov5s.yaml --weights yolov5s.pt --name tutorial --nosave --cache
# Out:
# Using torch 1.7.0+cu101 CPU
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/yolov5s.yaml', data='./mask/data.yaml', device='', epochs=5, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[149, 149], local_rank=-1, log_imgs=10, multi_scale=False, name='tutorial', noautoanchor=False, nosave=True, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/tutorial7', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-11-17 06:01:09.850849: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Install Weights & Biases for experiment logging via 'pip install wandb' (recommended)
# ...

# %%
Image(filename='runs/train/tutorial7/train_batch0.jpg', width=900)  # view augmented training mosaics

# %%
Image(filename='runs/train/tutorial7/train_batch1.jpg', width=900)  # view augmented training mosaics

# %%
Image(filename='runs/train/tutorial7/train_batch2.jpg', width=900)  # view augmented training mosaics
